# %% [markdown]
# ### Importing the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading data

# %%
raw_data = pd.read_csv('Glassdoor_DA_Jobs.csv')

# %%
df = raw_data.copy()
df
# Out:
#                                              Job_Title  \
# 0                            Data Analyst (Kafka, API)
# 1    FBT Data Operations - Document Control & Engin...
# 2    Business system owner Order management – Senio...
# 3                Vendor Master Data Management Analyst
# 4                              Global Planning Analyst
# ..                                                 ...
# 419             Senior Associate - Data Change Analyst
# 420                    Senior Analyst - Data Analytics
# 421                           Manager - Data Analytics
# 422                      Business Analyst ( 2+ years )
# 423                                 Data Analyst - SCM
#
#                                           Company_Name  Ratings   Location  \
# 0                                             ITI Data      4.0  Hyderābād
# 1                                            BP Energy      3.9       Pune
# 2                                            Sanofi EU      4.0  Hyderābād
# 3                                            Sanofi EU      4.0  Hyderābād
# 4                                            BP Energy      3.9       Pune
# ..                                                 ...      ...        ...
# 419                            Macquarie Group Limited      3.8    Gurgaon
# 420                                Verint Systems Inc.      4.0  Bengaluru
# 421                                          1 Finance      4.9     Mumbai
# 422  Bhanzu( formerly Exploring Infinities Edtech P...      3.9  Bengaluru
# 423                                     Ingersoll Rand      3.6    Chennai
#
#                 Salary_Estimates            Company_Size Founding_Year  \
# 0     ₹4L - ₹6L (Glassdoor Est.)    201 to 500 Employees          1999
# 1     ₹6L - ₹7L (Glassdoor Est.)        10000+ Employees          1908
# 2    ₹8L - ₹10L (Glassdoor Est.)        10000+ Employees          1973
# 3    ₹6L - ₹10L (Glassdoor Est.)        10000+ Employees          1973
# 4    ₹7L - ₹10L (Glassdoor Est.)        10000+ Employees          1908
# ..                           ...                     ...           ...
# 419  ₹8L - ₹10L (Glassdoor Est.)        10000+ Employees          1969
# 420        ₹10L (Glassdoor Est.)  1001 to 5000 Employees          1994
# 421   ₹5L - ₹6L (Glassdoor Est.)     51 to 200 Employees          2022
# 422    ₹5L - ₹8L (Employer Est.)   501 to 1000 Employees          2020
# 423   ₹3L - ₹7L (Glassdoor Est.)        10000+ Employees          1859
#
#                   Type                                 Industry  \
# 0    Company - Private  Information Technology Support Services
# 1     Company - Public                       Energy & Utilities
# 2     Company - Public                Biotech & Pharmaceuticals
# 3     Company - Public                Biotech & Pharmaceuticals
# 4     Company - Public                       Energy & Utilities
# ..                 ...                                      ...
# 419   Company - Public            Investment & Asset Management
# 420   Company - Public  Enterprise Software & Network Solutions
# 421  Company - Private            Investment & Asset Management
# 422  Company - Private              Primary & Secondary Schools
# 423   Company - Public                  Machinery Manufacturing
#
#                                Sector                   Revenue
# 0              Information Technology  Unknown / Non-Applicable
# 1           Energy, mining, utilities        $10+ billion (USD)
# 2    Pharmaceutical and biotechnology        $10+ billion (USD)
# 3    Pharmaceutical and biotechnology        $10+ billion (USD)
# 4           Energy, mining, utilities        $10+ billion (USD)
# ..                                ...                       ...
# 419                           Finance   $5 to $10 billion (USD)
# 420            Information Technology  Unknown / Non-Applicable
# 421                           Finance  Unknown / Non-Applicable
# 422                         Education  Unknown / Non-Applicable
# 423                     Manufacturing   $5 to $10 billion (USD)
#
# [424 rows x 11 columns]

# %% [markdown]
# ### Going through data

# %%
df.columns.array
# Out:
# <NumpyExtensionArray>
# [       'Job_Title',     'Company_Name',          'Ratings',
#          'Location', 'Salary_Estimates',     'Company_Size',
#     'Founding_Year',             'Type',         'Industry',
#            'Sector',          'Revenue']
# Length: 11, dtype: object

# %%
df.isna().sum()
# Out:
# Job_Title           0
# Company_Name        0
# Ratings             0
# Location            0
# Salary_Estimates    0
# Company_Size        0
# Founding_Year       0
# Type                0
# Industry            0
# Sector              0
# Revenue             0
# dtype: int64

# %%
df.describe(include='O')
# Out:
#            Job_Title Company_Name Location             Salary_Estimates  \
# count            424          424      424                          424
# unique           269          257       37                           76
# top     Data Analyst    BP Energy     Pune  ₹7L - ₹10L (Glassdoor Est.)
# freq              62           71      105                           39
#
#             Company_Size Founding_Year              Type            Industry  \
# count                424           424               424                 424
# unique                 8            82                 9                  40
# top     10000+ Employees          1908  Company - Public  Energy & Utilities
# freq                 229            72               230                  74
#
#                         Sector             Revenue
# count                      424                 424
# unique                      19                  10
# top     Information Technology  $10+ billion (USD)
# freq                       105                 171

# %% [markdown]
# ### Cleaning data
# - Salary Parsing
# - Age of the company
# - Removing company part from Type column

# %% [markdown]
# ### Salary Parsing
# 1. Removing `(Glassdoor Est.)` part from `Salary_Estimates` column
# 2. Remving `L` and `T` part
# 3. There are some columns with `per hour` values in `Salary_Estimates` column removing them
# 4. Creating 3 new columns (Min_Salary, Max_Salary, and Avg_Salary) columns

# %%
df['Salary_Estimates'] = df['Salary_Estimates'].apply(lambda x:x.split('(')[0])

# %%
df.head()
# Out:
#                                            Job_Title Company_Name  Ratings  \
# 0                          Data Analyst (Kafka, API)     ITI Data      4.0
# 1  FBT Data Operations - Document Control & Engin...    BP Energy      3.9
# 2  Business system owner Order management – Senio...    Sanofi EU      4.0
# 3              Vendor Master Data Management Analyst    Sanofi EU      4.0
# 4                            Global Planning Analyst    BP Energy      3.9
#
#     Location Salary_Estimates          Company_Size Founding_Year  \
# 0  Hyderābād       ₹4L - ₹6L   201 to 500 Employees          1999
# 1       Pune       ₹6L - ₹7L       10000+ Employees          1908
# 2  Hyderābād      ₹8L - ₹10L       10000+ Employees          1973
# 3  Hyderābād      ₹6L - ₹10L       10000+ Employees          1973
# 4       Pune      ₹7L - ₹10L       10000+ Employees          1908
#
#                 Type                                 Industry  \
# 0  Company - Private  Information Technology Support Services
# 1   Company - Public                       Energy & Utilities
# 2   Company - Public                Biotech & Pharmaceuticals
# 3   Company - Public                Biotech & Pharmaceuticals
# 4   Company - Public                       Energy & Utilities
#
#                              Sector                   Revenue
# 0            Information Technology  Unknown / Non-Applicable
# 1         Energy, mining, utilities        $10+ billion (USD)
# 2  Pharmaceutical and biotechnology        $10+ billion (USD)
# 3  Pharmaceutical and biotechnology        $10+ billion (USD)
# 4         Energy, mining, utilities        $10+ billion (USD)

# %%
df['Salary_Estimates'] = df['Salary_Estimates'].apply(lambda x:x.replace('L','').replace('₹','').replace('T',''))

# %%
df['Salary_Estimates'].unique()
# Out:
# array(['4 - 6 ', '6 - 7 ', '8 - 10 ', '6 - 10 ', '7 - 10 ', '5 - 8 ',
#        '3 - 7 ', '6 - 9 ', '4 - 10 ', '7 - 9 ', '3 - 6 ', '5 - 12 ',
#        '3 - 8 ', '4 - 7 ', '2 - 10 ', '1 ', '6 - 8 ', '4 - 8 ', '5 - 7 ',
#        '7 - 12 ', '5 - 6 ', '2 - 3 ', '8 - 9 ', '5 - 9 ', '1 - 2 ',
#        '3 - 10 ', '3 - 5 ', '2 - 4 ', '3 - 4 ', '4 ', '7 - 8 ',
#        '15 - 25 ', '3 - 9 ', '6 - 15 ', '20 - 30 ',
#        '516.00 - 682.00 Per hour ', '10 - 12 ', '10 ', '5 - 10 ', '6 ',
#        '9 - 11 ', '4 - 9 ', '4 - 5 ', '9 - 10 ', '15 - 20 ', '25 - 50 ',
#        '50 - 80 ', '3 ', '7 ', '25 - 60 ', '25.00 Per hour ', '2 - 7 ',
#        '12 ', '2 - 5 ', '1 - 7 ', '2 ', '5 ', '2 - 6 ', '96 - 1 ',
#        '11 - 12 ', '6 - 11 ', '8 - 15 ', '35 '], dtype=object)

# %%
df = df[~df['Salary_Estimates'].str.contains('Per hour', na=False)]

# %%
df['Salary_Estimates'].unique()
# Out:
# array(['4 - 6 ', '6 - 7 ', '8 - 10 ', '6 - 10 ', '7 - 10 ', '5 - 8 ',
#        '3 - 7 ', '6 - 9 ', '4 - 10 ', '7 - 9 ', '3 - 6 ', '5 - 12 ',
#        '3 - 8 ', '4 - 7 ', '2 - 10 ', '1 ', '6 - 8 ', '4 - 8 ', '5 - 7 ',
#        '7 - 12 ', '5 - 6 ', '2 - 3 ', '8 - 9 ', '5 - 9 ', '1 - 2 ',
#        '3 - 10 ', '3 - 5 ', '2 - 4 ', '3 - 4 ', '4 ', '7 - 8 ',
#        '15 - 25 ', '3 - 9 ', '6 - 15 ', '20 - 30 ', '10 - 12 ', '10 ',
#        '5 - 10 ', '6 ', '9 - 11 ', '4 - 9 ', '4 - 5 ', '9 - 10 ',
#        '15 - 20 ', '25 - 50 ', '50 - 80 ', '3 ', '7 ', '25 - 60 ',
#        '2 - 7 ', '12 ', '2 - 5 ', '1 - 7 ', '2 ', '5 ', '2 - 6 ',
#        '96 - 1 ', '11 - 12 ', '6 - 11 ', '8 - 15 ', '35 '], dtype=object)

# %% [markdown]
# #### Creating Min_Salary, Max_Salary, and Avg_Salary columns

# %%
has_hyphen = df['Salary_Estimates'].str.contains('-')
df_range = df[has_hyphen].copy()

# %%
salary_split = df_range['Salary_Estimates'].str.split('-', expand=True)

# %%
salary_split
# Out:
#       0     1
# 0    4     6
# 1    6     7
# 2    8    10
# 3    6    10
# 4    7    10
# ..   ..   ...
# 418  4     9
# 419  8    10
# 421  5     6
# 422  5     8
# 423  3     7
#
# [404 rows x 2 columns]

# %%
df_range['Min_Salary'] = pd.to_numeric(salary_split[0], errors='coerce')
df_range['Max_Salary'] = pd.to_numeric(salary_split[1], errors='coerce')

# %%
df_single = df[~has_hyphen].copy()

# %%
df_single['Min_Salary'] = pd.to_numeric(df_single['Salary_Estimates'].str.strip(), errors='coerce')
df_single['Max_Salary'] = df_single['Min_Salary'].copy()

# %%
df_preprocessed = pd.concat([df_range, df_single], ignore_index=True)

# %%
df_preprocessed['Avg_Salary'] = (df_preprocessed['Min_Salary'] + df_preprocessed['Max_Salary']) / 2

# %%
df = df.merge(df_preprocessed[['Min_Salary', 'Max_Salary', 'Avg_Salary']], left_index=True, right_index=True, how='left')

# %%
df
# Out:
#                                              Job_Title  \
# 0                            Data Analyst (Kafka, API)
# 1    FBT Data Operations - Document Control & Engin...
# 2    Business system owner Order management – Senio...
# 3                Vendor Master Data Management Analyst
# 4                              Global Planning Analyst
# ..                                                 ...
# 419             Senior Associate - Data Change Analyst
# 420                    Senior Analyst - Data Analytics
# 421                           Manager - Data Analytics
# 422                      Business Analyst ( 2+ years )
# 423                                 Data Analyst - SCM
#
#                                           Company_Name  Ratings   Location  \
# 0                                             ITI Data      4.0  Hyderābād
# 1                                            BP Energy      3.9       Pune
# 2                                            Sanofi EU      4.0  Hyderābād
# 3                                            Sanofi EU      4.0  Hyderābād
# 4                                            BP Energy      3.9       Pune
# ..                                                 ...      ...        ...
# 419                            Macquarie Group Limited      3.8    Gurgaon
# 420                                Verint Systems Inc.      4.0  Bengaluru
# 421                                          1 Finance      4.9     Mumbai
# 422  Bhanzu( formerly Exploring Infinities Edtech P...      3.9  Bengaluru
# 423                                     Ingersoll Rand      3.6    Chennai
#
#     Salary_Estimates            Company_Size Founding_Year               Type  \
# 0             4 - 6     201 to 500 Employees          1999  Company - Private
# 1             6 - 7         10000+ Employees          1908   Company - Public
# 2            8 - 10         10000+ Employees          1973   Company - Public
# 3            6 - 10         10000+ Employees          1973   Company - Public
# 4            7 - 10         10000+ Employees          1908   Company - Public
# ..               ...                     ...           ...                ...
# 419          8 - 10         10000+ Employees          1969   Company - Public
# 420              10   1001 to 5000 Employees          1994   Company - Public
# 421           5 - 6      51 to 200 Employees          2022  Company - Private
# 422           5 - 8    501 to 1000 Employees          2020  Company - Private
# 423           3 - 7         10000+ Employees          1859   Company - Public
#
#                                     Industry  \
# 0    Information Technology Support Services
# 1                         Energy & Utilities
# 2                  Biotech & Pharmaceuticals
# 3                  Biotech & Pharmaceuticals
# 4                         Energy & Utilities
# ..                                       ...
# 419            Investment & Asset Management
# 420  Enterprise Software & Network Solutions
# 421            Investment & Asset Management
# 422              Primary & Secondary Schools
# 423                  Machinery Manufacturing
#
#                                Sector                   Revenue  Min_Salary  \
# 0              Information Technology  Unknown / Non-Applicable         4.0
# 1           Energy, mining, utilities        $10+ billion (USD)         6.0
# 2    Pharmaceutical and biotechnology        $10+ billion (USD)         8.0
# 3    Pharmaceutical and biotechnology        $10+ billion (USD)         6.0
# 4           Energy, mining, utilities        $10+ billion (USD)         7.0
# ..                                ...                       ...         ...
# 419                           Finance   $5 to $10 billion (USD)        35.0
# 420            Information Technology  Unknown / Non-Applicable        10.0
# 421                           Finance  Unknown / Non-Applicable        10.0
# 422                         Education  Unknown / Non-Applicable         NaN
# 423                     Manufacturing   $5 to $10 billion (USD)         NaN
#
#      Max_Salary  Avg_Salary
# 0           6.0         5.0
# 1           7.0         6.5
# 2          10.0         9.0
# 3          10.0         8.0
# 4          10.0         8.5
# ..          ...         ...
# 419        35.0        35.0
# 420        10.0        10.0
# 421        10.0        10.0
# 422         NaN         NaN
# 423         NaN         NaN
#
# [422 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Job_Title           0
# Company_Name        0
# Ratings             0
# Location            0
# Salary_Estimates    0
# Company_Size        0
# Founding_Year       0
# Type                0
# Industry            0
# Sector              0
# Revenue             0
# Min_Salary          2
# Max_Salary          2
# Avg_Salary          2
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %% [markdown]
# ### Age of Company

# %%
df
# Out:
#                                              Job_Title  \
# 0                            Data Analyst (Kafka, API)
# 1    FBT Data Operations - Document Control & Engin...
# 2    Business system owner Order management – Senio...
# 3                Vendor Master Data Management Analyst
# 4                              Global Planning Analyst
# ..                                                 ...
# 417                         Business Intelligence- MIS
# 418                        Financial Reporting Analyst
# 419             Senior Associate - Data Change Analyst
# 420                    Senior Analyst - Data Analytics
# 421                           Manager - Data Analytics
#
#                 Company_Name  Ratings   Location Salary_Estimates  \
# 0                   ITI Data      4.0  Hyderābād           4 - 6
# 1                  BP Energy      3.9       Pune           6 - 7
# 2                  Sanofi EU      4.0  Hyderābād          8 - 10
# 3                  Sanofi EU      4.0  Hyderābād          6 - 10
# 4                  BP Energy      3.9       Pune          7 - 10
# ..                       ...      ...        ...              ...
# 417           5paisa Capital      3.5     Mumbai           4 - 7
# 418                UPS India      3.5    Chennai           4 - 9
# 419  Macquarie Group Limited      3.8    Gurgaon          8 - 10
# 420      Verint Systems Inc.      4.0  Bengaluru              10
# 421                1 Finance      4.9     Mumbai           5 - 6
#
#                Company_Size Founding_Year               Type  \
# 0      201 to 500 Employees          1999  Company - Private
# 1          10000+ Employees          1908   Company - Public
# 2          10000+ Employees          1973   Company - Public
# 3          10000+ Employees          1973   Company - Public
# 4          10000+ Employees          1908   Company - Public
# ..                      ...           ...                ...
# 417    201 to 500 Employees            --   Company - Public
# 418        10000+ Employees          1907   Company - Public
# 419        10000+ Employees          1969   Company - Public
# 420  1001 to 5000 Employees          1994   Company - Public
# 421     51 to 200 Employees          2022  Company - Private
#
#                                     Industry  \
# 0    Information Technology Support Services
# 1                         Energy & Utilities
# 2                  Biotech & Pharmaceuticals
# 3                  Biotech & Pharmaceuticals
# 4                         Energy & Utilities
# ..                                       ...
# 417                                       --
# 418                      Shipping & Trucking
# 419            Investment & Asset Management
# 420  Enterprise Software & Network Solutions
# 421            Investment & Asset Management
#
#                                Sector                   Revenue  Min_Salary  \
# 0              Information Technology  Unknown / Non-Applicable         4.0
# 1           Energy, mining, utilities        $10+ billion (USD)         6.0
# 2    Pharmaceutical and biotechnology        $10+ billion (USD)         8.0
# 3    Pharmaceutical and biotechnology        $10+ billion (USD)         6.0
# 4           Energy, mining, utilities        $10+ billion (USD)         7.0
# ..                                ...                       ...         ...
# 417                                --  Unknown / Non-Applicable         3.0
# 418      Transportation and logistics        $10+ billion (USD)         3.0
# 419                           Finance   $5 to $10 billion (USD)        35.0
# 420            Information Technology  Unknown / Non-Applicable        10.0
# 421                           Finance  Unknown / Non-Applicable        10.0
#
#      Max_Salary  Avg_Salary
# 0           6.0         5.0
# 1           7.0         6.5
# 2          10.0         9.0
# 3          10.0         8.0
# 4          10.0         8.5
# ..          ...         ...
# 417         3.0         3.0
# 418         3.0         3.0
# 419        35.0        35.0
# 420        10.0        10.0
# 421        10.0        10.0
#
# [420 rows x 14 columns]

# %%
df.Founding_Year.unique()
# Out:
# array(['1999', '1908', '1973', '1869', '1850', '2005', '2015', '2014',
#        '1997', '1988', '2012', '--', '1872', '1982', '2008', '2017',
#        '1967', '2000', '1939', '2013', '1935', '2018', '1984', '1985',
#        '1974', '2011', '1887', '1945', '2016', '2003', '1928', '1932',
#        '1799', '1860', '1969', '1954', '1994', '1991', '2009', '1963',
#        '1930', '2004', '1870', '2006', '1989', '1998', '1966', '1996',
#        '1987', '1906', '1983', '2019', '1690', '1880', '2007', '2002',
#        '2020', '1698', '1923', '1913', '1921', '2010', '1947', '1781',
#        '1812', '1904', '1760', '1900', '1891', '1990', '1981', '1902',
#        '1857', '1919', '2022', '1968', '1865', '2001', '1986', '1916',
#        '1907'], dtype=object)

# %%
df[df.Founding_Year == '--']
# Out:
#                                       Job_Title  \
# 23                                 Data Analyst
# 31                       Associate Data Analyst
# 33   Sustainability Analyst, Data and Reporting
# 44                                 Data Analyst
# 46                      Junior Data Analyst (F)
# ..                                          ...
# 387                 Senior Finance Data Analyst
# 397                  Data Visualisation Analyst
# 408                             AI Data Analyst
# 410                      Business Analyst (MSI)
# 417                  Business Intelligence- MIS
#
#                               Company_Name  Ratings   Location  \
# 23                           HNM Solutions      4.3       Pune
# 31                                   Optum      3.5  Hyderābād
# 33                                     JLL      3.8  Bengaluru
# 44                                   Optum      3.5  Hyderābād
# 46                               coolboots      2.6    Gurgaon
# ..                                     ...      ...        ...
# 387                                Keyloop      4.3  Hyderābād
# 397                           Pulsus Group      4.2  Hyderābād
# 408  Techwyse IT Solutions Private Limited      3.8     Cochin
# 410                Maruti Suzuki India Ltd      3.8    Gurgaon
# 417                         5paisa Capital      3.5     Mumbai
#
#     Salary_Estimates          Company_Size Founding_Year               Type  \
# 23            3 - 6    51 to 200 Employees            --  Company - Private
# 31           2 - 10       10000+ Employees            --   Company - Public
# 33            6 - 8       10000+ Employees            --   Company - Public
# 44           2 - 10       10000+ Employees            --   Company - Public
# 46            4 - 8    51 to 200 Employees            --  Company - Private
# ..               ...                   ...           ...                ...
# 387           2 - 6                Unknown            --  Company - Private
# 397           2 - 4                Unknown            --  Company - Private
# 408              35                Unknown            --   Company - Public
# 410           4 - 7       10000+ Employees            --   Company - Public
# 417           4 - 7   201 to 500 Employees            --   Company - Public
#
#                                    Industry                   Sector  \
# 23                                       --                       --
# 31          Healthcare Services & Hospitals               Healthcare
# 33                              Real estate              Real estate
# 44          Healthcare Services & Hospitals               Healthcare
# 46                                       --                       --
# ..                                      ...                      ...
# 387                    Software Development   Information Technology
# 397                              Publishing  Media and communication
# 408                                      --                       --
# 410  Transportation Equipment Manufacturing            Manufacturing
# 417                                      --                       --
#
#                       Revenue  Min_Salary  Max_Salary  Avg_Salary
# 23   Unknown / Non-Applicable         3.0         6.0         4.5
# 31         $10+ billion (USD)         2.0        10.0         6.0
# 33    $5 to $10 billion (USD)         4.0         8.0         6.0
# 44         $10+ billion (USD)         5.0         6.0         5.5
# 46   Unknown / Non-Applicable         4.0         8.0         6.0
# ..                        ...         ...         ...         ...
# 387  Unknown / Non-Applicable         5.0         8.0         6.5
# 397  Unknown / Non-Applicable         4.0         8.0         6.0
# 408  Unknown / Non-Applicable         4.0         4.0         4.0
# 410        $10+ billion (USD)         7.0         7.0         7.0
# 417  Unknown / Non-Applicable         3.0         3.0         3.0
#
# [68 rows x 14 columns]

# %%
df['Founding_Year'] = df['Founding_Year'].replace('--', -1)

# %%
df['Founding_Year'] = df['Founding_Year'].astype(int)

# %%
# df['Age'] = 2025 - df['Founding_Year']
df['Age'] = df['Founding_Year'].apply(lambda x:x if x<1 else 2025-x)

# %%
df.head()
# Out:
#                                            Job_Title Company_Name  Ratings  \
# 0                          Data Analyst (Kafka, API)     ITI Data      4.0
# 1  FBT Data Operations - Document Control & Engin...    BP Energy      3.9
# 2  Business system owner Order management – Senio...    Sanofi EU      4.0
# 3              Vendor Master Data Management Analyst    Sanofi EU      4.0
# 4                            Global Planning Analyst    BP Energy      3.9
#
#     Location Salary_Estimates          Company_Size  Founding_Year  \
# 0  Hyderābād           4 - 6   201 to 500 Employees           1999
# 1       Pune           6 - 7       10000+ Employees           1908
# 2  Hyderābād          8 - 10       10000+ Employees           1973
# 3  Hyderābād          6 - 10       10000+ Employees           1973
# 4       Pune          7 - 10       10000+ Employees           1908
#
#                 Type                                 Industry  \
# 0  Company - Private  Information Technology Support Services
# 1   Company - Public                       Energy & Utilities
# 2   Company - Public                Biotech & Pharmaceuticals
# 3   Company - Public                Biotech & Pharmaceuticals
# 4   Company - Public                       Energy & Utilities
#
#                              Sector                   Revenue  Min_Salary  \
# 0            Information Technology  Unknown / Non-Applicable         4.0
# 1         Energy, mining, utilities        $10+ billion (USD)         6.0
# 2  Pharmaceutical and biotechnology        $10+ billion (USD)         8.0
# 3  Pharmaceutical and biotechnology        $10+ billion (USD)         6.0
# 4         Energy, mining, utilities        $10+ billion (USD)         7.0
#
#    Max_Salary  Avg_Salary  Age
# 0         6.0         5.0   26
# 1         7.0         6.5  117
# 2        10.0         9.0   52
# 3        10.0         8.0   52
# 4        10.0         8.5  117

# %%
df['Age'].sort_values()
# Out:
# 91      -1
# 109     -1
# 369     -1
# 107     -1
# 367     -1
#       ...
# 210    327
# 218    335
# 278    335
# 177    335
# 371    335
# Name: Age, Length: 420, dtype: int64

# %%
df[df['Age'] == 335]
# Out:
#                          Job_Title Company_Name  Ratings Location  \
# 177  Business Intelligence Analyst     Barclays      3.9     Pune
# 218               Business Analyst     Barclays      3.9     Pune
# 278                   Data Analyst     Barclays      3.9    Noida
# 371         Research Analyst - BA4     Barclays      3.9   Mumbai
#
#     Salary_Estimates      Company_Size  Founding_Year              Type  \
# 177          9 - 11   10000+ Employees           1690  Company - Public
# 218           7 - 8   10000+ Employees           1690  Company - Public
# 278           8 - 9   10000+ Employees           1690  Company - Public
# 371           8 - 9   10000+ Employees           1690  Company - Public
#
#               Industry   Sector             Revenue  Min_Salary  Max_Salary  \
# 177  Banking & Lending  Finance  $10+ billion (USD)         4.0         5.0
# 218  Banking & Lending  Finance  $10+ billion (USD)         5.0         8.0
# 278  Banking & Lending  Finance  $10+ billion (USD)         4.0         5.0
# 371  Banking & Lending  Finance  $10+ billion (USD)        15.0        20.0
#
#      Avg_Salary  Age
# 177         4.5  335
# 218         6.5  335
# 278         4.5  335
# 371        17.5  335

# %% [markdown]
# ###

# %%
df.head()
# Out:
#                                            Job_Title Company_Name  Ratings  \
# 0                          Data Analyst (Kafka, API)     ITI Data      4.0
# 1  FBT Data Operations - Document Control & Engin...    BP Energy      3.9
# 2  Business system owner Order management – Senio...    Sanofi EU      4.0
# 3              Vendor Master Data Management Analyst    Sanofi EU      4.0
# 4                            Global Planning Analyst    BP Energy      3.9
#
#     Location Salary_Estimates          Company_Size  Founding_Year  \
# 0  Hyderābād           4 - 6   201 to 500 Employees           1999
# 1       Pune           6 - 7       10000+ Employees           1908
# 2  Hyderābād          8 - 10       10000+ Employees           1973
# 3  Hyderābād          6 - 10       10000+ Employees           1973
# 4       Pune          7 - 10       10000+ Employees           1908
#
#                 Type                                 Industry  \
# 0  Company - Private  Information Technology Support Services
# 1   Company - Public                       Energy & Utilities
# 2   Company - Public                Biotech & Pharmaceuticals
# 3   Company - Public                Biotech & Pharmaceuticals
# 4   Company - Public                       Energy & Utilities
#
#                              Sector                   Revenue  Min_Salary  \
# 0            Information Technology  Unknown / Non-Applicable         4.0
# 1         Energy, mining, utilities        $10+ billion (USD)         6.0
# 2  Pharmaceutical and biotechnology        $10+ billion (USD)         8.0
# 3  Pharmaceutical and biotechnology        $10+ billion (USD)         6.0
# 4         Energy, mining, utilities        $10+ billion (USD)         7.0
#
#    Max_Salary  Avg_Salary  Age
# 0         6.0         5.0   26
# 1         7.0         6.5  117
# 2        10.0         9.0   52
# 3        10.0         8.0   52
# 4        10.0         8.5  117

# %%
df['Company_Size'].unique()
# Out:
# array(['201 to 500 Employees', '10000+ Employees',
#        '1001 to 5000 Employees', '501 to 1000 Employees',
#        '51 to 200 Employees', '5001 to 10000 Employees',
#        '1 to 50 Employees', 'Unknown'], dtype=object)

# %%
df['Type'].unique()
# Out:
# array(['Company - Private', 'Company - Public',
#        'Subsidiary or Business Segment', 'Unknown',
#        'Private Practice / Firm', 'Self-employed', 'Contract',
#        'College / University', 'Non-profit Organisation'], dtype=object)

# %%
df['Industry'].unique()
# Out:
# array(['Information Technology Support Services', 'Energy & Utilities',
#        'Biotech & Pharmaceuticals', 'Investment & Asset Management',
#        'Business consulting', 'Real estate', 'Internet & Web Services',
#        '--', 'Consumer Product Manufacturing',
#        'Healthcare Services & Hospitals',
#        'Enterprise Software & Network Solutions', 'Software Development',
#        'Stock Exchanges', 'Financial Transaction Processing',
#        'Computer Hardware Development', 'Research and development',
#        'HR Consulting', 'Transportation Equipment Manufacturing',
#        'Accounting & Tax', 'Rail Transportation', 'Banking & Lending',
#        'Motor Vehicle Dealers', 'Architectural & Engineering Services',
#        'Food & Beverage Manufacturing', 'Electronics Manufacturing',
#        'Education Support & Training Services', 'Chemical Manufacturing',
#        'Insurance Carriers', 'Machinery Manufacturing',
#        'Video Game Publishing', 'Advertising & Public Relations',
#        'Primary & Secondary Schools', 'Grocery Stores',
#        'Home Furniture & Housewares Stores', 'Gambling & Betting',
#        'Travel Agencies', 'Shipping & Trucking',
#        'Commercial Equipment Services', 'Telecommunications Services',
#        'Publishing'], dtype=object)

# %%
df['Sector'].unique()
# Out:
# array(['Information Technology', 'Energy, mining, utilities',
#        'Pharmaceutical and biotechnology', 'Finance',
#        'Management and consulting', 'Real estate', '--', 'Manufacturing',
#        'Healthcare', 'Human resources and staffing',
#        'Transportation and logistics', 'Retail and wholesale',
#        'Construction, repair and maintenance', 'Education', 'Insurance',
#        'Media and communication', 'Arts, entertainment and recreation',
#        'Hotel and travel accommodation', 'Telecommunications'],
#       dtype=object)

# %%
df['Revenue'].unique()
# Out:
# array(['Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$100 to $500 million (USD)', '$500 million to $1 billion (USD)',
#        '$25 to $50 million (USD)', '$5 to $10 billion (USD)',
#        '$1 to $5 million (USD)', 'Less than $1 million (USD)',
#        '$2 to $5 billion (USD)', '$5 to $25 million (USD)'], dtype=object)

# %%
df.to_csv('Cleaned_Data.csv', index=False)

# %%
pd.read_csv('Cleaned_Data.csv')
# Out:
#                                              Job_Title  \
# 0                            Data Analyst (Kafka, API)
# 1    FBT Data Operations - Document Control & Engin...
# 2    Business system owner Order management – Senio...
# 3                Vendor Master Data Management Analyst
# 4                              Global Planning Analyst
# ..                                                 ...
# 415                         Business Intelligence- MIS
# 416                        Financial Reporting Analyst
# 417             Senior Associate - Data Change Analyst
# 418                    Senior Analyst - Data Analytics
# 419                           Manager - Data Analytics
#
#                 Company_Name  Ratings   Location Salary_Estimates  \
# 0                   ITI Data      4.0  Hyderābād           4 - 6
# 1                  BP Energy      3.9       Pune           6 - 7
# 2                  Sanofi EU      4.0  Hyderābād          8 - 10
# 3                  Sanofi EU      4.0  Hyderābād          6 - 10
# 4                  BP Energy      3.9       Pune          7 - 10
# ..                       ...      ...        ...              ...
# 415           5paisa Capital      3.5     Mumbai           4 - 7
# 416                UPS India      3.5    Chennai           4 - 9
# 417  Macquarie Group Limited      3.8    Gurgaon          8 - 10
# 418      Verint Systems Inc.      4.0  Bengaluru              10
# 419                1 Finance      4.9     Mumbai           5 - 6
#
#                Company_Size  Founding_Year               Type  \
# 0      201 to 500 Employees           1999  Company - Private
# 1          10000+ Employees           1908   Company - Public
# 2          10000+ Employees           1973   Company - Public
# 3          10000+ Employees           1973   Company - Public
# 4          10000+ Employees           1908   Company - Public
# ..                      ...            ...                ...
# 415    201 to 500 Employees             -1   Company - Public
# 416        10000+ Employees           1907   Company - Public
# 417        10000+ Employees           1969   Company - Public
# 418  1001 to 5000 Employees           1994   Company - Public
# 419     51 to 200 Employees           2022  Company - Private
#
#                                     Industry  \
# 0    Information Technology Support Services
# 1                         Energy & Utilities
# 2                  Biotech & Pharmaceuticals
# 3                  Biotech & Pharmaceuticals
# 4                         Energy & Utilities
# ..                                       ...
# 415                                       --
# 416                      Shipping & Trucking
# 417            Investment & Asset Management
# 418  Enterprise Software & Network Solutions
# 419            Investment & Asset Management
#
#                                Sector                   Revenue  Min_Salary  \
# 0              Information Technology  Unknown / Non-Applicable         4.0
# 1           Energy, mining, utilities        $10+ billion (USD)         6.0
# 2    Pharmaceutical and biotechnology        $10+ billion (USD)         8.0
# 3    Pharmaceutical and biotechnology        $10+ billion (USD)         6.0
# 4           Energy, mining, utilities        $10+ billion (USD)         7.0
# ..                                ...                       ...         ...
# 415                                --  Unknown / Non-Applicable         3.0
# 416      Transportation and logistics        $10+ billion (USD)         3.0
# 417                           Finance   $5 to $10 billion (USD)        35.0
# 418            Information Technology  Unknown / Non-Applicable        10.0
# 419                           Finance  Unknown / Non-Applicable        10.0
#
#      Max_Salary  Avg_Salary  Age
# 0           6.0         5.0   26
# 1           7.0         6.5  117
# 2          10.0         9.0   52
# 3          10.0         8.0   52
# 4          10.0         8.5  117
# ..          ...         ...  ...
# 415         3.0         3.0   -1
# 416         3.0         3.0  118
# 417        35.0        35.0   56
# 418        10.0        10.0   31
# 419        10.0        10.0    3
#
# [420 rows x 15 columns]
